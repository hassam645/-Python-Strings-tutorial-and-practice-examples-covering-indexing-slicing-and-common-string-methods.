# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# **Syntax**

# %%
print("hi my name is HBS")
# Out:
# hi my name is HBS

# %% [markdown]
# **Indentation:**

# %%
if 5>2:
    print("five is greater then two")
# Out:
# five is greater then two

# %%
if 5>2:
print("five is greater than two")
# Out:
#   File "/tmp/ipykernel_16/1204385867.py", line 2
#     print("five is greater than two")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %% [markdown]
# **How to write Values in our Python**

# %%
print("my school")
print("my class")
print("my Rllno")

# %%
print(100)
print(50)

# %%
print("HBS",17)

# %% [markdown]
# **Comments**

# %%
#this is the comment
print("IT Subject")

# %%
"""
I love my UOE
"""

# %% [markdown]
# **Variable**

# %%
age=12;
Age=13;
AGE=14;
_age=15;

# %%
a,b,c="computer","Math","Physics"
print(a)
print(b)
print(c)

# %%
a=b=c="computer"
print(a)
print(b)
print(c)

# %%
x = "awesome"
def myfunc():
  print("Python is " + x)
myfunc()

# %%
x = "awesome"
def myfunc():
    x="good"
    print("Python is " + x)
    myfunc()
    print("Python is " + x)

# %%
def myfunc():
  global x
  x = "fantastic"

myfunc()

print("Python is " + x)

# %%
x = "good"
def myfunc():
    global x
    x = "fantastic"
myfunc()
print("Python is " + x)

# %% [markdown]
# **Data Type**

# %%
x="Hello, my name is HBS."
print(type(x))
x=20
print(type(x))
x=2.1
print(type(x))
x=["apple", "banana", "mango"]
print(type(x))
x=True
print(type(x))
x=frozenset({"apple", "banana", "mango"})

# %% [markdown]
# **Python Numbers**

# %%
a=2
b=2.4
c=8j
print(type(a))
print(type(b))
print(type(c))

# %%
a=2
b=2.4
c=8j
x=float(a)
y=int(b)
z=complex(a)
print(x)
print(y)
print(z)
print(type(x))
print(type(y))
print(type(z))

# %% [markdown]
# **Random Range**

# %%
import random
random.randrange(1,10)

# %% [markdown]
# **Casting**

# %%
a=int(12)
b=int(2.5)
c=int("2")
print(a)
print(b)
print(c)

# %%
a=float(12)
b=float(2.5)
c=float("2")
print(a)
print(b)
print(c)

# %%
a=str(12)
b=str(2.5)
c=str("2")
print(a)
print(b)
print(c)

# %% [markdown]
# **Strings**

# %%
print("hello i am student of UOE")

# %%
"""my name is Ali i am student of class 10th"""

# %% [markdown]
# **Slicing String**

# %%
b="Claude computing is the latest technology of the world"
print(b[2:5])

# %%
a="many many happy returns of the day"
print(a[-6:-3])

# %% [markdown]
# **Modify String**

# %%
a="Information Technology"
print(a.upper())

# %%
a="Information Technology"
print(a.lower())

# %%
a="Information Technology"
print(a.strip())

# %%
a="Information Technology"
print(a.replace("T","t"))

# %% [markdown]
# **Concatenate String**

# %%
a="BOP"
b="NBP"
c=a+b
print(c)

# %%
a="BOP"
b="NBP"
c=a+""+b
print(c)

# %% [markdown]
# **Format String**

# %%
age=17
txt=f"my name is john, i am {age} years old"
print(txt)

# %%
price=59
txt=f"the price is {price:.2f} dollars"
print(txt)

# %% [markdown]
# **Escape Sequence**

# %%
#\b,\f,\n,\r,\t
